# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadshoaib549/pytorch/blob/main/pyturch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)

if torch.cuda.is_available():
    print("GPU is available!")
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    print("GPU not available. Using CPU.")
# Out:
# 2.10.0+cu128
# GPU is available!
# Using GPU: Tesla T4

# %%
#this is for the Empty
torch.empty(2,3)
# Out:
# tensor([[2.5213e-40, 0.0000e+00, 1.0790e-43],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00]])
